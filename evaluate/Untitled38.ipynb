# %%
# !rm -rf /content/Quantathon-demo-2

# %%
# !git clone -b tin --single-branch https://github.com/nn-tin/Quantathon-demo-2.git
# Out:
# Cloning into 'Quantathon-demo-2'...
# remote: Enumerating objects: 123, done.
# remote: Counting objects: 100% (123/123), done.
# remote: Compressing objects: 100% (89/89), done.
# remote: Total 123 (delta 32), reused 115 (delta 24), pack-reused 0 (from 0)
# Receiving objects: 100% (123/123), 284.12 KiB | 8.88 MiB/s, done.
# Resolving deltas: 100% (32/32), done.

# %%
# !python -m pip install --upgrade pip
# !python -m pip install -r /content/Quantathon-demo-2/backend/requirements-quantum-colab.txt

# %%
import os
os.environ["CUDAQ_TARGET"] = "nvidia"
os.environ["REQUIRE_CUDAQ"] = "1"

# %%
import cudaq
cudaq.set_target("nvidia")
print("CUDA-Q target:", cudaq.get_target().name)
# Out:
# CUDA-Q target: nvidia

# %%
# !CUDAQ_TARGET=nvidia REQUIRE_CUDAQ=1 python /content/Quantathon-demo-2/evaluate/test-gpu/compare_hybrid_milp.py --target nvidia --require-cudaq
# Out:
# Pipeline-aligned mock comparison: hybrid vs MILP
# requested_target=nvidia
# requested_qubits=[12, 18, 20, 24, 28]
# instances_per_qubit=3
# mapping_csv=/content/Quantathon-demo-2/evaluate/test-gpu/generator-qubit-candidate-mapping.csv
#
# HybridQAOA solve start requested_target=nvidia qubits=12 top_k=10 allow_numpy_fallback=False
# 2026-07-25 07:15:40,168 INFO numexpr.utils: NumExpr defaulting to 2 threads.
# QAOA runtime mode=cudaq requested_target=nvidia qubits=12 depth=1 shots=256 optimizer_evals=8
# QAOA executor initialized backend=cudaq target=nvidia parameter_count=2
# objective eval 1 start
# objective eval 1 estimate done value=7.462871012312971
# objective eval 1 estimate_ms=567.026
# objective eval 2 start
# objective eval 2 estimate done value=7.486501820487025
# objective eval 2 estimate_ms=60.486
# objective eval 3 start
# objective eval 3 estimate done value=9.175206426836429
# objective eval 3 estimate_ms=57.485
# objective eval 4 start
# ...

# %%
# !python /content/Quantathon-demo-2/evaluate/test-gpu/compare_hybrid_milp.py --qubits 32 36
# Out:
# Pipeline-aligned mock comparison: hybrid vs MILP
# requested_target=nvidia
# requested_qubits=[32, 36]
# instances_per_qubit=3
# mapping_csv=/content/Quantathon-demo-2/evaluate/test-gpu/generator-qubit-candidate-mapping.csv
#
# HybridQAOA solve start requested_target=nvidia qubits=32 top_k=28 allow_numpy_fallback=True
# 2026-07-25 07:01:13,858 INFO numexpr.utils: NumExpr defaulting to 2 threads.
# QAOA runtime mode=cudaq requested_target=nvidia qubits=32 depth=1 shots=256 optimizer_evals=8
# QAOA executor initialized backend=cudaq target=nvidia parameter_count=2
# objective eval 1 start
# objective eval 1 estimate failed: RuntimeError: requested size is too big
